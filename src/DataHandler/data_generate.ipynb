# %%
# !/usr/bin/env python3
import os
import csv
import google.generativeai as genai
import re
import pandas as pd
import time
import glob

# %% [markdown]
# ### Base model data generating

# %%
API_KEY_1 =""
API_KEY_2 = ""
API_KEY_3 = ""
genai.configure(api_key=API_KEY_3)

# System constants
FILE_NAME = "disease_data.csv"
SYSTEMS = [
    "CirculatorySystem", "RespiratorySystem", "DigestiveSystem", "NervousSystem",
    "MusculoskeletalSystem", "EndocrineSystem", "ImmuneSystem", "UrinarySystem",
    "ReproductiveSystem", "IntegumentarySystem"
]


# Functions for duplicated data handling
def get_existing_disease_names(filename):
    """Read existing disease names from the CSV file to avoid duplicates."""
    if not os.path.exists(filename) or os.path.getsize(filename) == 0:
        return set()
    
    try:
        df = pd.read_csv(filename)
        # Extract disease names (part before the colon), normalize to lowercase and strip spaces
        existing_names = set(df['Disease_Information'].str.split(':', n=1).str[0].str.strip().str.lower())
        return existing_names
    except Exception as e:
        # Handle potential errors in reading the file
        print(f"Lỗi khi đọc tên bệnh từ CSV: {e}")
        return set()

# Functions for data generation and processing
def filter_new_data(new_data, existing_names_set):
    """Lọc dữ liệu mới để loại bỏ trùng lặp dựa trên Tên Bệnh."""
    filtered_data = []
    duplicates_count = 0
    
    for info, system in new_data:
        # Lấy tên bệnh (phần trước dấu hai chấm)
        disease_name = info.split(':', 1)[0].strip().lower()
        
        # Kiểm tra trùng lặp
        if disease_name not in existing_names_set:
            filtered_data.append([info, system]) # Dùng [] vì csv.writerows yêu cầu list of lists/tuples
        else:
            duplicates_count += 1
            
    return filtered_data, duplicates_count

# Functions for prompt preparation
def prepare_simple_prompt(num_entries):
    """Create a simple prompt for generating disease data."""
    
    return f"""
    You are an expert medical data generator. Your task is to generate {num_entries} new disease entries following the EXACT format: ('Disease Name: Characteristic Symptoms and bodily impact', 'Body System'),.

    The generated diseases must be randomly distributed among the following systems: {', '.join(SYSTEMS)}.

    **OUTPUT REQUIREMENTS:**
    1. Generate exactly {num_entries} unique entries.
    2. Output ONLY the lines of data (Python tuples).
    3. Each line MUST start with '(' and end with '),' on a new line.
    4. Use ONLY English for the disease information.
    5. Use ONLY the system names provided in the list above.
    """
# Functions for Gemini API interaction and data parsing
def generate_and_parse_diseases(prompt):
    """Call Gemini API to generate disease data and parse the response."""
    try:
        # Initialize the model
        model = genai.GenerativeModel('gemini-2.5-flash')
        
        print("Calling Gemini API...")
        response = model.generate_content(prompt)
        raw_text = response.text

        # Ensure to capture multiline entries with re.DOTALL
        pattern = re.compile(r"\('(.*?)',\s*'(.*?)'\),", re.DOTALL)
        
        matches = pattern.findall(raw_text)
        
        parsed_data = []
        for match in matches:
            # match[0] is 'disease information', match[1] is 'system'
            parsed_data.append([match[0].strip(), match[1].strip()])
            
        return parsed_data

    except Exception as e:
        print(f"Error during Gemini API call or parsing: {e}")
        return []
def append_to_csv(data, filename=FILE_NAME):
    """Save new disease data to CSV file, appending if file exists."""
    if not data:
        print("No new data to save.")
        return

    file_exists = os.path.exists(filename)
    header = ['Disease_Information', 'Body_System']

    try:
        # Using 'a' mode to append data
        with open(filename, 'a', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            
            # Only write header if file doesn't exist or is empty
            if not file_exists or os.path.getsize(filename) == 0:
                writer.writerow(header)
                
            # Write new data rows
            writer.writerows(data)
            
        print(f"\n- Finished saving {len(data)} new entries to {filename}.")

    except Exception as e:
        print(f"Error writing to CSV: {e}")

# %%
# Just run the main loop
if __name__ == "__main__":
    
    # Begin loop to reach target N
    while True:
        # 1. Determine current and needed counts
        existing_names_set = get_existing_disease_names(FILE_NAME)
        current_count = len(existing_names_set)
        TARGET_N = 1000  # <--- TARGET NUMBER OF RECORDS TO ACHIEVE
        BATCH_SIZE = 20 # <--- NUMBER OF DISEASES TO GENERATE PER API CALL
        print("-" * 50)
        print(f"Number of existing records: {current_count}")
        
        # Stop if target reached
        if current_count >= TARGET_N:
            print(f"Reached target of {TARGET_N} records. Exiting.")
            break
            
        remaining_needed = TARGET_N - current_count
        
        # The last API call doesn't need to generate full BATCH_SIZE if fewer are needed
        entries_to_generate = min(BATCH_SIZE, remaining_needed)
        print(f"Needing {remaining_needed} more records. Requesting Gemini to generate {entries_to_generate} records.")

        # 2. Prepare prompt and call Gemini API
        prompt = prepare_simple_prompt(entries_to_generate)
        
        # 3. Generate and parse data from Gemini
        final_data_raw = generate_and_parse_diseases(prompt) 
        
        if not final_data_raw:
            print("Cannot get data from Gemini. Pausing to check API error.")
            break # Exit if API error

        # 4. Filter out duplicates
        unique_new_data, duplicates_removed = filter_new_data(final_data_raw, existing_names_set)
        
        if duplicates_removed > 0:
            print(f"Eliminated {duplicates_removed} duplicate entries from generated data.")

        # 5. Save only unique new data to CSV
        if unique_new_data:

            append_to_csv(unique_new_data)
            print(f"Saved {len(unique_new_data)} new records to file: {FILE_NAME}")

        else:
            print("- All generated data were duplicates or invalid. Retrying later.")
            
        # Sleep to avoid rate limiting
        time.sleep(5)
# Out:
# --------------------------------------------------
# Tổng số bản ghi hiện có: 0
# Cần thêm 1000 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 20
# Cần thêm 980 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 40
# Cần thêm 960 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 59
# Cần thêm 941 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 79
# Cần thêm 921 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 99
# Cần thêm 901 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 119
# Cần thêm 881 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 139
# Cần thêm 861 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 159
# Cần thêm 841 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 177
# Cần thêm 823 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 195
# Cần thêm 805 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 214
# Cần thêm 786 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 233
# Cần thêm 767 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 252
# Cần thêm 748 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 3 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 17 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 17 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 269
# Cần thêm 731 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 288
# Cần thêm 712 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 308
# Cần thêm 692 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 328
# Cần thêm 672 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 3 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 17 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 17 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 345
# Cần thêm 655 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 364
# Cần thêm 636 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 384
# Cần thêm 616 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 3 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 17 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 17 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 401
# Cần thêm 599 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 420
# Cần thêm 580 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 439
# Cần thêm 561 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 457
# Cần thêm 543 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 476
# Cần thêm 524 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 495
# Cần thêm 505 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 514
# Cần thêm 486 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 533
# Cần thêm 467 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 553
# Cần thêm 447 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 573
# Cần thêm 427 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 4 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 16 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 16 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 589
# Cần thêm 411 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 608
# Cần thêm 392 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 627
# Cần thêm 373 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 645
# Cần thêm 355 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 664
# Cần thêm 336 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 684
# Cần thêm 316 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 704
# Cần thêm 296 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 722
# Cần thêm 278 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 4 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 16 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 16 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 738
# Cần thêm 262 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 758
# Cần thêm 242 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 776
# Cần thêm 224 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 795
# Cần thêm 205 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 815
# Cần thêm 185 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 835
# Cần thêm 165 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 4 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 16 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 16 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 851
# Cần thêm 149 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 6 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 14 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 14 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 865
# Cần thêm 135 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 20 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 885
# Cần thêm 115 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 904
# Cần thêm 96 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 923
# Cần thêm 77 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 4 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 16 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 16 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 939
# Cần thêm 61 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 958
# Cần thêm 42 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 977
# Cần thêm 23 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do Gemini không tuân thủ.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 995
# Cần thêm 5 bản ghi. Đang yêu cầu Gemini sinh 5 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 5 bản ghi mới vào tệp: disease_data.csv
# Đã lưu tiếp 5 bản ghi mới vào tệp: disease_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 1000
# 🎉 Đã đạt mục tiêu 1000 bản ghi. Kết thúc chương trình.

# %% [markdown]
# ### KG data handling

# %%
# Prompt for extracting unique symptoms from disease descriptions
def create_extraction_prompt(descriptions: list) -> str:
    """Generate a prompt to extract unique symptoms from disease descriptions."""
    
    # Chuyển danh sách mô tả thành định dạng dễ đọc cho mô hình (ví dụ: gạch đầu dòng)
    input_text = "\n".join([f"- {desc}" for desc in descriptions])

    PROMPT = f"""
    Based on the following list of disease descriptions, your task is to extract all unique, distinct, and characteristic symptoms and clinical findings.

    Follow these strict rules:
    1. Extract ONLY the specific medical symptoms (e.g., 'nausea', 'fractures', 'cough').
    2. Do NOT include general impacts (e.g., 'impacting motor control', 'affecting digestion', 'impaired movement').
    3. Standardize and normalize related symptoms (e.g., use 'cough' instead of 'chronic cough' unless the severity is the unique finding).
    4. Ensure the final list contains ONLY unique entries (no duplicates).
    5. Present the output as a single, comma-separated list of items.
    6. Do NOT include any explanations, markdown code blocks, or headers in your final output.

--- INPUT DESCRIPTIONS ---
{input_text}
--- END OF INPUT ---

OUTPUT LIST (Comma-separated, unique symptoms only):
"""
    return PROMPT

# Function to call Gemini API and process the output
def extract_and_clean_symptoms(descriptions: list) -> list:
    """Call Gemini API to extract and clean unique symptoms from disease descriptions."""
    
    if not descriptions:
        return []
    
    try:
        prompt = create_extraction_prompt(descriptions)
        model = genai.GenerativeModel('gemini-2.5-flash')
        
        print("\nCalling Gemini API for symptom extraction...")
        
        # Call API
        response = model.generate_content(prompt)
        raw_text = response.text.strip()
        
        # Post-processing
        
        # 1. Clean text: Remove unwanted whitespace and newlines
        cleaned_text = re.sub(r'[\r\n]+', '', raw_text).strip()
        
        # 2. Split string and normalize (lowercase, trim spaces)
        symptoms_list = [
            item.strip().lower() 
            for item in cleaned_text.split(',') 
            if item.strip()
        ]
        
        # 3. Filter unique symptoms and sort
        unique_symptoms = sorted(list(set(symptoms_list)))
        
        return unique_symptoms

    except Exception as e:
        print(f"- Error during Gemini API call or processing: {e}")
        return []

# Function to load disease descriptions from CSV
def load_disease_descriptions(filename: str) -> list:
    """Read CSV file and return a list of disease description strings."""
    
    if not os.path.exists(filename):
        print(f"- Error: File {filename} not found.")
        return []

    try:
        # Read the CSV file using pandas
        df = pd.read_csv(filename)
        
        # Check if the required column exists
        if 'Disease_Information' not in df.columns:
            print("- Error: CSV file does not contain 'Disease_Information' column.")
            return []
            
        # Extract data from that column into a list
        descriptions = df['Disease_Information'].astype(str).tolist()
        
        print(f"- Successfully loaded {len(descriptions)} disease descriptions from file.")
        return descriptions

    except Exception as e:
        print(f"- Error reading CSV file: {e}")
        return []

# --- Main Execution ---
try:
    all_descriptions = load_disease_descriptions(FILE_NAME)
    # 1. Ensure we have input data
    if not all_descriptions:
        print("- No input data to process.")
    else:
        INPUT_DATA = all_descriptions
    # 2. Call extraction function
    unique_traits_list = extract_and_clean_symptoms(INPUT_DATA)

    # 3. Print results
    if unique_traits_list:
        print("\n" + "="*60)
        print("RESULT: LIST OF UNIQUE, STANDARDIZED SYMPTOMS:")
        print("="*60)
        for i, trait in enumerate(unique_traits_list):
            # Print with capitalized first letter for readability
            print(f"{i+1}. {trait.capitalize()}")
        print(f"\nNumber of unique symptoms extracted: {len(unique_traits_list)}")
    else:
        print("\n- Cannot extract symptoms. Please check API connection and input data.")

except ValueError as e:
    print(f"- Error initializing: {e}")
except Exception as e:
    print(f"- Error: {e}")
# Out:
# ✅ Đã tải thành công 1000 mô tả bệnh lý từ file.
#
# Đang gọi API Gemini để phân tích ngữ nghĩa và rút trích các tính trạng duy nhất...
#
# ============================================================
# KẾT QUẢ DANH SÁCH CÁC TÍNH TRẠNG DUY NHẤT (Đã Chuẩn Hóa):
# ============================================================
# 1. Abdominal distension
# 2. Abdominal pain
# 3. Abnormal bone growth
# 4. Abnormal cell growth in reproductive organs
# 5. Abnormal growth of glandular tissue
# 6. Abnormal keratin production
# 7. Abnormal nevus formation
# 8. Abnormal proliferation of epithelial cells in stomach
# 9. Abnormal stress response
# 10. Absence of germ cells in testes
# 11. Absence of menstrual cycles
# 12. Absent puberty
# 13. Accelerated metabolism
# 14. Acne
# 15. Acute respiratory distress
# 16. Airway constriction
# 17. Airway obstruction
# 18. Altered body contour
# 19. Altered sleep patterns
# 20. Alternating hypoglycemia and hyperglycemia
# 21. Anemia
# 22. Angina
# 23. Anxiety
# 24. Asphyxiation
# 25. Aspiration risk
# 26. Asynchronous hormone production
# 27. Asynchronous processing of sensory input
# 28. Atrophy
# 29. Atrophy of motor neurons
# 30. Attacks on brain tissue
# 31. Attacks on lymphatic tissues
# 32. Attacks on red blood cells
# 33. Attacks on skin cells
# 34. Attacks on thymic cells
# 35. Auditory hallucinations
# 36. Autoimmune attacks
# 37. Autoimmune destruction of insulin-producing cells
# 38. Backward flow of urine
# 39. Bacterial infection of bone
# 40. Bacterial overgrowth
# 41. Basal ganglia dysfunction
# 42. Behavioral changes
# 43. Benign tumors in uterus
# 44. Black tarry stools
# 45. Bloating
# 46. Blockage of capillaries
# 47. Blockage of major veins
# 48. Blockage of tiny blood vessels
# 49. Blood clots
# 50. Blood clotting issues
# 51. Blood pooling in lower extremities
# 52. Blood pooling in peripheral muscles
# 53. Blood pressure fluctuations
# 54. Blood sugar dysregulation
# 55. Bluish discoloration of skin
# 56. Blunting of small intestinal villi
# 57. Bone breakdown
# 58. Bone brittleness
# 59. Bone demineralization
# 60. Bone density loss
# 61. Bone fragility
# 62. Bone pain
# 63. Bone-on-bone friction
# 64. Brain fog
# 65. Breakdown of alveolar walls
# 66. Breakdown of muscle fibers
# 67. Breakdown of skin proteins
# 68. Brittle bones
# 69. Brittle hair
# 70. Brittle ligaments
# 71. Bronchospasms
# 72. Bruising
# 73. Bumpy skin texture
# 74. Burning pain
# 75. Calcification of muscle tendons and ligaments
# 76. Calcium crystals in tendons
# 77. Calcium deposits in arterial walls
# 78. Calcium deposits in kidney tubules
# 79. Calcium stones in kidney tubules
# 80. Cardiac arrest
# 81. Cardiac strain
# 82. Cardiac workload increase
# 83. Cell death in kidney tubules
# 84. Changes in energy
# 85. Chest pain
# 86. Chest tightness
# 87. Chronic kidney inflammation
# 88. Chronic swelling of lymph nodes
# 89. Cirrhosis
# 90. Claudication
# 91. Cognitive decline
# 92. Cognitive impairment
# 93. Cognitive slowing
# 94. Cold extremities
# 95. Cold intolerance
# 96. Collagen degradation
# 97. Collagen overgrowth
# 98. Collapse of lung alveoli
# 99. Collapse of tracheal rings
# 100. Compromised immune response
# 101. Compromised skin barrier function
# 102. Constipation
# 103. Constriction of bronchioles
# 104. Contraction of muscle fascia
# 105. Conversion of cartilage into bone
# 106. Coordination issues
# 107. Cough
# 108. Crackling sounds in lungs
# 109. Cramping
# 110. Crystal deposits in lung tissue
# 111. Crystal deposits in renal tubules
# 112. Crystal deposits in skin
# 113. Cysts in kidneys
# 114. Cysts on the ovaries
# 115. Damage to myelin sheath of nerves
# 116. Damage to peripheral nerves
# 117. Decline in kidney filtering capacity
# 118. Decline in lung capacity
# 119. Decreased blood flow to extremities
# 120. Decreased range of motion
# 121. Deep muscle pain
# 122. Deep vein thrombosis risk
# 123. Deformed nails
# 124. Degeneration of cerebellum
# 125. Degeneration of myelin sheath
# 126. Degeneration of nerve cells in gut
# 127. Degeneration of neurotransmitter receptors
# 128. Degradation of muscle fibers
# 129. Degradation of somatic cells
# 130. Dehydration
# 131. Delay in gastric emptying
# 132. Delayed puberty
# 133. Delirium
# 134. Depressions in the skin
# 135. Destruction of bone structure
# 136. Deterioration of myelin sheath
# 137. Developmental abnormalities
# 138. Diabetic complications
# 139. Diarrhea
# 140. Difficulties with motor coordination
# 141. Difficulty emptying bladder completely
# 142. Difficulty performing fine motor tasks
# 143. Difficulty with balance
# 144. Difficulty with cognitive processing
# 145. Difficulty with fluid balance
# 146. Difficulty with movement
# 147. Difficulty with speech
# 148. Difficulty with waste elimination
# 149. Digestive discomfort
# 150. Digestive distress
# 151. Digestive disturbances
# 152. Diminished oxygen exchange
# 153. Diminished pathogen recognition
# 154. Dislocations
# 155. Disordered contractions of ureters
# 156. Disordered intestinal muscle contractions
# 157. Disordered movement of food through intestines
# 158. Disordered peristalsis
# 159. Disorientation
# 160. Disrupted peristalsis
# 161. Disruption of nerve function in intestines
# 162. Disruption of reproductive cycles
# 163. Dizzy spells
# 164. Dry skin
# 165. Dysfunction of testes
# 166. Dysfunctional gonadal glands
# 167. Dysfunctional sebaceous glands
# 168. Dysregulation of adrenal hormone release
# 169. Early satiety
# 170. Easily damaged skin
# 171. Easy bruising
# 172. Ectopic implantation
# 173. Eczema-like symptoms
# 174. Edema
# 175. Elastin degradation
# 176. Electrolyte imbalance
# 177. Enlargement of heart muscle
# 178. Enlargement of oil glands
# 179. Epidermal scarring
# 180. Epileptic seizures
# 181. Erratic heart rhythms
# 182. Erratic neuronal firing
# 183. Erratic signal transmission between neurons
# 184. Erratic thickening of outer skin layer
# 185. Excessive bleeding
# 186. Excessive elasticity of ligaments
# 187. Excessive firing of neuronal synapses
# 188. Excessive growth of fibrous tissue in liver
# 189. Excessive hormone production
# 190. Excessive oil production
# 191. Excessive sebum production
# 192. Excessive sweating
# 193. Excessively dry skin
# 194. Facial numbness
# 195. Facial tingling
# 196. Failure of ovarian follicles
# 197. Failure of ovarian follicles to mature
# 198. Failure of ovarian follicles to release eggs
# 199. Fainting spells
# 200. Fasciculations
# 201. Fatigue
# 202. Fatty tumors
# 203. Fever
# 204. Fibrous web-like structures in arteries
# 205. Fine motor control loss
# 206. Fine motor tremors
# 207. Flank pain
# 208. Fleeting sensory distortions
# 209. Fluctuating hormone levels
# 210. Fluctuations in blood sugar
# 211. Fluctuations in thyroid hormone levels
# 212. Fluid loss
# 213. Fluid-filled cysts in ovarian tissue
# 214. Fluid-filled sacs on ovaries
# 215. Foamy urine
# 216. Fracture risk
# 217. Fragility fractures
# 218. Frequent fractures
# 219. Frequent urination
# 220. Functional loss of gonads
# 221. Fungal overgrowth in bronchial tubes
# 222. Genetic impairment of immune system
# 223. Growth of endometrial tissue outside uterus
# 224. Growth retardation
# 225. Hardening of alveolar sacs
# 226. Hardening of arterial walls
# 227. Hardening of kidney tissue
# 228. Hardening of liver tissue
# 229. Hardening of testicular tissue
# 230. Headaches
# 231. Heart attack
# 232. Heart failure
# 233. Heart muscle weakening
# 234. Heavy menstrual bleeding
# 235. Hematuria
# 236. High blood pressure
# 237. High cholesterol
# 238. Hormonal deficiencies
# 239. Hormonal imbalances
# 240. Hormone imbalances
# 241. Hot flashes
# 242. Hydronephrosis
# 243. Hypercalcemia
# 244. Hyperglycemia
# 245. Hypermobility of joints
# 246. Hyperpigmentation
# 247. Hypersensitivity of airways
# 248. Hypersensitivity of the skin
# 249. Hypertension
# 250. Hypoglycemia
# 251. Hypopigmentation
# 252. Hypotension
# 253. Hypoxemia
# 254. Hypoxia
# 255. Immobility
# 256. Immunodeficiency
# 257. Impaired barrier function of the skin
# 258. Impaired bile flow
# 259. Impaired bile production
# 260. Impaired bladder emptying
# 261. Impaired blood return to heart
# 262. Impaired ciliary action
# 263. Impaired clearance of pathogens from airways
# 264. Impaired detoxification
# 265. Impaired digestion
# 266. Impaired filtration
# 267. Impaired fluid drainage
# 268. Impaired function of insulin-producing cells
# 269. Impaired gas exchange
# 270. Impaired kidney function
# 271. Impaired liver function
# 272. Impaired movement of food through intestines
# 273. Impaired mucus clearance
# 274. Impaired nutrient delivery to tissues
# 275. Impaired phagocytic cells
# 276. Impaired reabsorption in kidney tubules
# 277. Impaired secretion in kidney tubules
# 278. Impaired skin elasticity
# 279. Impaired skin sensation
# 280. Impaired stress adaptation
# 281. Impaired stress response
# 282. Impaired thermoregulation
# 283. Impaired venous return
# 284. Inability to regulate glycogen breakdown
# 285. Inability to release glycogen
# 286. Inability to store glycogen
# 287. Inadequate hormone production
# 288. Increased cancer risk
# 289. Increased infection risk
# 290. Increased metabolism
# 291. Increased risk of malignancy
# 292. Increased skin fragility
# 293. Indigestion
# 294. Infertility
# 295. Inflammation in joints
# 296. Inflammation of bladder
# 297. Inflammation of blood vessels
# 298. Inflammation of epididymis
# 299. Inflammation of intestinal lining
# 300. Inflammation of kidney glomeruli
# 301. Inflammation of kidneys
# 302. Inflammation of small blood vessels
# 303. Inflammation of the skin
# 304. Inhaled crystalline particles in lung
# 305. Intermittent visual disturbances
# 306. Internal bleeding
# 307. Interrupted signal transmission between neurons
# 308. Intestinal inflammation
# 309. Involuntary eye movements
# 310. Involuntary movements
# 311. Involuntary muscle contractions
# 312. Irregular bowel movements
# 313. Irregular heart rhythm
# 314. Irregular menstruation
# 315. Ischemia
# 316. Itching
# 317. Itchy patches beneath skin
# 318. Jaundice
# 319. Joint fusion
# 320. Joint instability
# 321. Joint pain
# 322. Joint stiffness
# 323. Kidney damage
# 324. Kidney dysfunction
# 325. Kidney failure
# 326. Kidney stone formation
# 327. Kidney strain
# 328. Kidney swelling
# 329. Lack of immune cell types
# 330. Large pores
# 331. Leakage of proteins into urine
# 332. Leakage of red blood cells into urine
# 333. Leg swelling
# 334. Lesions
# 335. Ligament rupture
# 336. Lightheadedness
# 337. Limb coldness
# 338. Limitations in movement
# 339. Liver enlargement
# 340. Liver scarring
# 341. Loss of bladder muscle tone
# 342. Loss of brain cells
# 343. Loss of coordination
# 344. Loss of glandular tissue in stomach lining
# 345. Loss of hair
# 346. Loss of mobility
# 347. Loss of myelin sheath in brain and spinal cord
# 348. Loss of nerve control over bladder
# 349. Loss of skin elasticity
# 350. Loss of subcutaneous fat
# 351. Loss of synaptic connections between immune cells
# 352. Loss of synaptic connections in brain
# 353. Low blood pressure
# 354. Low hormone levels
# 355. Low-grade infections
# 356. Lumps
# 357. Lymphedema
# 358. Malabsorption
# 359. Malformation of liver and spleen
# 360. Memory lapses
# 361. Memory loss
# 362. Menstrual irregularities
# 363. Metabolic acceleration
# 364. Metabolic acidosis
# 365. Metabolic complications
# 366. Metabolic disturbances
# 367. Metabolic dysfunction
# 368. Metabolic imbalances
# 369. Microfractures
# 370. Microscopic crystals in tendon sheaths
# 371. Migraines
# 372. Mobility restriction
# 373. Mood swings
# 374. Motor incoordination
# 375. Motor weakness
# 376. Mouth sores
# 377. Mucus overproduction
# 378. Mucus production
# 379. Multi-organ failure
# 380. Muscle rigidity
# 381. Muscle spasms
# 382. Muscle stiffness
# 383. Muscle wasting
# 384. Muscle weakness
# 385. Musculoskeletal pain
# 386. Nail dystrophy
# 387. Narrowing of bronchial airways
# 388. Narrowing of capillaries
# 389. Narrowing of the trachea
# 390. Narrowing of the ureters
# 391. Nausea
# 392. Nerve pain
# 393. Numbness
# 394. Nutrient deficiencies
# 395. Nutrient malabsorption
# 396. Obstructed urine flow
# 397. Obstruction of small airways
# 398. Obstruction of urine flow
# 399. Oily skin
# 400. Open wounds
# 401. Opportunistic infections
# 402. Organ damage
# 403. Organ hypoperfusion
# 404. Organ hypoxia
# 405. Over-filtering by kidney glomeruli
# 406. Over-response to allergens
# 407. Over-responsiveness of pituitary gland
# 408. Overactivity of thyroid gland
# 409. Overflow incontinence
# 410. Overgrowth of adrenal glands
# 411. Overgrowth of fibrous tissue beneath skin
# 412. Overgrowth of sebaceous glands
# 413. Overproduction of adrenal cortisol
# 414. Overproduction of adrenal hormones
# 415. Overproduction of lymphocytes
# 416. Overproduction of thyroid hormones
# 417. Oxygen exchange impairment
# 418. Pain
# 419. Pain triggered by light
# 420. Pain triggered by temperature changes
# 421. Painful skin lesions
# 422. Palpitations
# 423. Paralysis
# 424. Paranoia
# 425. Peeling of the skin
# 426. Pelvic pain
# 427. Perforation risk
# 428. Personality changes
# 429. Pituitary erratic growth
# 430. Pituitary erratic metabolism
# 431. Pituitary erratic reproductive hormone levels
# 432. Polyuria
# 433. Poor response to pathogens
# 434. Porous glomerular capillaries
# 435. Portal hypertension
# 436. Postural deformities
# 437. Premature decline in ovarian function
# 438. Premature drying of ovarian follicles
# 439. Premature menopause
# 440. Pro-inflammatory cytokines release
# 441. Profound immunosuppression
# 442. Prolonged menstrual bleeding
# 443. Protein in urine
# 444. Protein leakage
# 445. Protein loss in urine
# 446. Proteinuria
# 447. Purple skin lesions
# 448. Pus-filled bumps on skin
# 449. Pustules
# 450. Radiating pain
# 451. Raised nodules
# 452. Rapid changes in metabolism
# 453. Rapid contractions of stomach muscles
# 454. Rapid heart rate
# 455. Rapid heartbeat
# 456. Rapid shallow breathing
# 457. Rapid weight changes
# 458. Rapid weight gain
# 459. Raw skin areas
# 460. Recurrent infections
# 461. Recurrent respiratory distress
# 462. Recurrent respiratory infections
# 463. Red skin patches
# 464. Reduced ability of kidneys to filter waste products
# 465. Reduced blood flow
# 466. Reduced elasticity of alveolar sacs
# 467. Reduced function of reproductive organs
# 468. Reduced lung elasticity
# 469. Reduced oxygen absorption
# 470. Reduced physical stamina
# 471. Reduced pumping efficiency
# 472. Reduced range of motion
# 473. Reduced sperm count
# 474. Reduced sperm motility
# 475. Reduced sperm production
# 476. Reduced testosterone production
# 477. Reduced urine output
# 478. Reduction in lymphocytes
# 479. Reflux
# 480. Renal strain
# 481. Reproductive dysfunction
# 482. Reproductive issues
# 483. Respiratory distress
# 484. Restricted joint movement
# 485. Restricted lung expansion
# 486. Rough skin
# 487. Rough skin patches
# 488. Salt imbalance
# 489. Scaly skin
# 490. Scaly skin lesions
# 491. Scarring of blood vessels in kidneys
# 492. Scarring of kidney tissue
# 493. Scarring of testicular tissue
# 494. Scrotal pain
# 495. Secondary sexual characteristic regression
# 496. Sensitive skin
# 497. Sensitivity to touch
# 498. Sensory distortion
# 499. Sensory overload
# 500. Sexual dysfunction
# 501. Sharp pain
# 502. Shedding of skin layers
# 503. Shock
# 504. Shortening of muscle and fascia
# 505. Shortness of breath
# 506. Shrinking of reproductive organs
# 507. Shrinking of the testicles
# 508. Silvery scales
# 509. Skeletal deformities
# 510. Skeletal pain
# 511. Skin blistering
# 512. Skin cracking
# 513. Skin discoloration
# 514. Skin dryness
# 515. Skin fragility
# 516. Skin irritation
# 517. Skin laxity
# 518. Skin necrosis
# 519. Skin pigmentation changes
# 520. Sleep disturbances
# 521. Slow heartbeat
# 522. Slow wound healing
# 523. Slowing of metabolic processes
# 524. Slowing of stomach emptying
# 525. Slurred speech
# 526. Softening of tracheal rings
# 527. Spasmodic narrowing of bronchial airways
# 528. Splenomegaly
# 529. Stiff joints
# 530. Stiffening of alveolar walls
# 531. Stiffening of heart muscle walls
# 532. Stiffening of joint capsules
# 533. Stiffening of lung tissue
# 534. Stiffness
# 535. Stiffness of muscle fascia
# 536. Straining of heart muscle
# 537. Stress intolerance
# 538. Stretchable ligaments
# 539. Stridor
# 540. Stroke
# 541. Sunken skin areas
# 542. Susceptibility to bacterial infections
# 543. Susceptibility to fungal infections
# 544. Swelling
# 545. Swollen lymph nodes
# 546. Systemic inflammation
# 547. Tachycardia
# 548. Temporary blindness
# 549. Tendency for lung air sacs to collapse
# 550. Tender points
# 551. Thick skin
# 552. Thickening of blood
# 553. Thickening of skin
# 554. Thickening of uterine lining
# 555. Thinning of skin
# 556. Thinning of stomach lining
# 557. Tightening of muscle and fascia
# 558. Tissue damage
# 559. Tissue death in stomach lining
# 560. Tissue hypoxia
# 561. Toxin buildup
# 562. Transformation of muscle tissue into bone
# 563. Tremors
# 564. Trigger points
# 565. Triggered by irritants
# 566. Ulceration
# 567. Uncontrollable constriction of bronchioles
# 568. Uncontrolled bursts of neuronal activity
# 569. Uncontrolled movements
# 570. Uncontrolled regrowth in kidney tubules
# 571. Uncontrolled release of inflammatory cytokines
# 572. Uncoordinated firing of neuronal synapses
# 573. Underactive thyroid
# 574. Underdeveloped secondary sexual characteristics
# 575. Underdevelopment of germ cells in testes
# 576. Underproduction of adrenal hormones
# 577. Underproduction of pituitary hormones
# 578. Underproduction of thyroid hormones
# 579. Unexplained weight loss
# 580. Unpredictable bowel movements
# 581. Unpredictable fluctuations in energy
# 582. Unpredictable fluctuations in mood
# 583. Unresponsiveness to sex hormones
# 584. Unsteady gait
# 585. Uremic symptoms
# 586. Ureteral spasms
# 587. Urinary incontinence
# 588. Urinary retention
# 589. Urinary tract infections
# 590. Urine backup
# 591. Urine reflux
# 592. Venous stasis ulcers
# 593. Venous ulcers
# 594. Vertigo
# 595. Virilization in females
# 596. Visible clusters of tiny blood vessels
# 597. Vision loss
# 598. Vision problems
# 599. Visual field defects
# 600. Vomiting
# 601. Vomiting blood
# 602. Wasting of ligaments
# 603. Wasting of lymph nodes
# 604. Wasting of lymphatic vessels
# 605. Wasting of stomach lining
# 606. Weakening of arterial walls
# 607. Weakening of bones
# 608. Weakening of heart muscle fibers
# 609. Weakness in ligaments
# 610. Weight gain
# 611. Weight loss
# 612. Wheezing
# 613. Widespread inflammation
# 614. Widespread muscle pain
# 615. Widespread tissue hypoxia
# 616. Wrinkles
#
# Tổng số tính trạng duy nhất được rút trích: 616

# %%
# Prompt for augmenting symptoms into OWL/RDF Turtle format
def create_augmentation_prompt(traits: list) -> str:
    """Generate a prompt asking Gemini to classify symptoms into Systems and Organs, then create Turtle blocks."""
    
    # Define the standard structure of an entry (similar to your provided example)
    EXAMPLE_ENTRY = """
:NewSymptomName rdf:type :Symptom ;
    rdfs:label "New Symptom Label" ;
    :associatedWith :ExistingOrgan ;
    :confidenceScore "X.X"^^xsd:float ;
    :specificityScore "Y.Y"^^xsd:float ;
    :prevalenceScore "Z.Z"^^xsd:float ;
    :priorityRank N .
"""
    
    # List of valid organs (as per your specification)
    VALID_ORGANS = ":Heart, :Arteries, :Veins, :Capillaries, :Lungs, :Trachea, :Bronchi, :Stomach, :Liver, :SmallIntestine, :LargeIntestine, :Brain, :SpinalCord, :Nerves, :Bones, :Muscles, :Joints, :PituitaryGland, :ThyroidGland, :AdrenalGlands, :LymphNodes, :Spleen, :BoneMarrow, :Kidneys, :Ureters, :Bladder, :Testes, :Prostate, :Ovaries, :Uterus, :Skin, :Hair, :Nails."

    PROMPT = f"""
You are an expert in biomedical ontology development. Your task is to generate OWL/RDF Turtle entries for the following list of new symptoms, integrating them into the existing Knowledge Graph structure.

--- EXISTING CONTEXT ---
1. **Properties:** All required properties (e.g., :associatedWith, :confidenceScore) are already defined in the KG header.
2. **Valid Organs:** The only organs you can link to are: {VALID_ORGANS}
3. **Requirement:** The generated symptom must be logically associated with one of these existing organs.

--- INSTRUCTION ---
For each symptom in the list below, generate a complete OWL/RDF Turtle block.

RULES:
1. **URI Name (e.g., :AbdominalPain):** Convert the symptom label (e.g., 'abdominal pain') to CamelCase.
2. **rdfs:label:** Use the original, properly formatted label.
3. **:associatedWith:** Map the symptom to the SINGLE, MOST LIKELY valid :Organ from the list above.
4. **Scores:** Assign realistic float values between 0.1 and 1.0 (e.g., "0.8"^^xsd:float).
5. **:priorityRank (CRITICAL):** Assign a logical integer rank (1, 2, 3, etc.) representing the priority in a clinical differential diagnosis process. **Rank 1 must be assigned to the organ/system association that is the most acutely life-threatening or requires the most urgent rule-out (e.g., Myocardial Infarction for Chest Pain).** Use higher numbers for less urgent associations.
6. **OUTPUT FORMAT:** Output the entries grouped by the Body System the associated Organ belongs to, separated by comments (e.g., # Digestive System Augmentations).

--- NEW SYMPTOMS LIST ---
{unique_traits_list}

--- EXAMPLE OF REQUIRED FORMAT ---
{EXAMPLE_ENTRY.strip()}

BEGIN GENERATION (Output ONLY the Turtle triples and grouping comments):
"""
    return PROMPT

# Function to call Gemini API and get OWL/RDF Turtle blocks
def generate_owl_augmentation(traits: list) -> str:
    """Call Gemini to generate OWL/RDF Turtle blocks for the entire list of traits."""
    
    prompt = create_augmentation_prompt(traits)
    
    try:
        model = genai.GenerativeModel('gemini-2.5-flash')
        
        print(f"\nCalling Gemini API for OWL/RDF augmentation of {len(traits)} symptoms...")
        
        response = model.generate_content(prompt)
        # Return raw text, expecting it to be the formatted Turtle block
        return response.text.strip()

    except Exception as e:
        print(f"- Error during Gemini API call or processing: {e}")
        return ""

# --- MAIN EXECUTION BLOCK --- 
try:
    # Split unique_traits_list into 6 roughly equal parts
    n_splits = 6
    chunk_size = len(unique_traits_list) // n_splits + (len(unique_traits_list) % n_splits > 0)
    chunks = [unique_traits_list[i:i + chunk_size] for i in range(0, len(unique_traits_list), chunk_size)]

    print("\n" + "="*80)
    print("ReSULT: OWL/RDF AUGMENTATION OUTPUT (Turtle/N3):")
    print("="*80)

    # Define prefixes to write at the top of the output file
    PREFIXES = """
@prefix : <http://example.org/human_body#> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix owl: <http://www.w3.org/2002/07/owl#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
\n"""

    OUTPUT_FILE = "new_symptom_augmentations.ttl"

    # Write to output file
    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        f.write(PREFIXES)  # Write prefixes only once at the top

        # Loop through chunks
        for idx, chunk in enumerate(chunks, 1):
            print(f"\n--- PROCESSING CHUNK {idx}/{len(chunks)} (size = {len(chunk)}) ---")
            
            owl_triples_block = generate_owl_augmentation(chunk)

            # Write the block to file if not empty
            if owl_triples_block:
                f.write(owl_triples_block + "\n")
                f.write("----------------------------------------------------------------------------\n")
                print(f"- Finished chunk {idx}, written to file.")
            else:
                print(f"- Chunk {idx} has no OWL data.")
            time.sleep(5)  # Avoid rate limiting
    print(f"\n--- FINISHED, output file: {OUTPUT_FILE} ---\n")

except ValueError as e:
    print(f"- Error initializing: {e}")
except Exception as e:
    print(f"- Error: {e}")
# Out:
# ================================================================================
# KẾT QUẢ OWL/RDF AUGMENTATION (Turtle/N3):
# ================================================================================
#
# --- ĐANG XỬ LÝ CHUNK 2/6 (số phần tử = 103) ---
#
# Đang gọi Gemini để tạo 103 khối OWL/RDF...
# ✓ Hoàn thành chunk 2, đã ghi vào file.
#
# --- ĐANG XỬ LÝ CHUNK 3/6 (số phần tử = 103) ---
#
# Đang gọi Gemini để tạo 103 khối OWL/RDF...
# ✓ Hoàn thành chunk 3, đã ghi vào file.
#
# --- ĐANG XỬ LÝ CHUNK 4/6 (số phần tử = 103) ---
#
# Đang gọi Gemini để tạo 103 khối OWL/RDF...
# ✓ Hoàn thành chunk 4, đã ghi vào file.
#
# --- ĐANG XỬ LÝ CHUNK 5/6 (số phần tử = 103) ---
#
# Đang gọi Gemini để tạo 103 khối OWL/RDF...
# ✓ Hoàn thành chunk 5, đã ghi vào file.
#
# --- ĐANG XỬ LÝ CHUNK 6/6 (số phần tử = 103) ---
#
# Đang gọi Gemini để tạo 103 khối OWL/RDF...
# ✓ Hoàn thành chunk 6, đã ghi vào file.
#
# --- ĐANG XỬ LÝ CHUNK 7/6 (số phần tử = 101) ---
#
# Đang gọi Gemini để tạo 101 khối OWL/RDF...
# ✓ Hoàn thành chunk 7, đã ghi vào file.
#
# --- HOÀN TẤT, file kết quả: new_symptom_augmentations.ttl ---

# %%
INPUT_FILE = "text.txt"  # new_symptom_augmentations.ttl but changed to txt for processing
OUTPUT_FILE = "text_dedup_blocks.txt" # Output file after deduplication and formatting

# Read input file
with open(INPUT_FILE, "r", encoding="utf-8") as f:
    lines = f.readlines()

# 1. Split into blocks based on symptoms
# A block starts with a line containing ":Symptom" and ends with a line containing "."
# Lines outside blocks are treated as separate blocks (e.g., comments, separators)
blocks = []
current_block = []
for line in lines:
    if line.strip().startswith(":") and "rdf:type :Symptom" in line:
        if current_block:
            blocks.append(current_block)
        current_block = [line]
    elif current_block:
        current_block.append(line)
        if line.strip().endswith("."):
            blocks.append(current_block)
            current_block = []
    else:
        if line.strip() != "":  # Ignore empty lines outside blocks
            blocks.append([line])

# 2. Remove duplicate symptom blocks based on the symptom name
# Keep the first occurrence, remove subsequent ones
seen = set()
unique_blocks = []
for block in blocks:
    header = block[0].strip() if block else ""
    if header.startswith(":") and "rdf:type :Symptom" in header:
        name = header.split()[0]  # ví dụ ":Angina"
        if name not in seen:
            unique_blocks.append(block)
            seen.add(name)
    else:
        unique_blocks.append(block)

# Normarlize formatting within each block
# - Remove empty lines within blocks
# - Ensure comments start with "#" and are followed by a separator line
cleaned_blocks = []
for block in unique_blocks:
    new_block = []
    for line in block:
        if line.strip() == "":
            continue
        if line.lstrip().startswith("#"):
            new_block.append(line.rstrip() + "\n")
            new_block.append("-" * 100 + "\n")
        else:
            new_block.append(line)
    cleaned_blocks.append(new_block)

# Merge blocks back into final lines with exactly one blank line between blocks
final_lines = []
for i, block in enumerate(cleaned_blocks):
    final_lines.extend(block)
    if i < len(cleaned_blocks) - 1:
        final_lines.append("\n")  # 1 blank line between blocks

# Write to output file
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    f.writelines(final_lines)

print(f"Finished writing cleaned data to {OUTPUT_FILE}.")
# Out:
# ✅ Đã lọc trùng, format lại file -> text_dedup_blocks.txt

# %% [markdown]
# ### Client data generating

# %%
# Define the folder path containing CSV files
FOLDER_PATH = r"D:\Hoàng Phong\University stuff\Khoa luan\Graph Federated Learning\data\medical"

# Function to read all CSV files and extract existing disease names
def get_all_existing_disease_names(folder_path):
    """
    Read all CSV files in the folder and return a set of all existing disease names to avoid duplicates.
    """
    all_names = set()
    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))
    for file in csv_files:
        try:
            df = pd.read_csv(file)
            # Extract disease names (part before the colon), normalize to lowercase and strip spaces
            existing_names = set(df['Disease_Information'].str.split(':', n=1).str[0].str.strip().str.lower())
            return existing_names
        except Exception as e:
            # Handle potential errors in reading the file
            print(f"- Error reading disease names from CSV: {e}")
            return set()
    return all_names

# Ensure the CSV file exists with the correct header
def ensure_file_exists(file_path):
    """
    Generate a new CSV file with the default header if it doesn't exist.
    """
    if not os.path.exists(file_path):
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        df = pd.DataFrame(columns=["Disease information","System"])  # chỉnh lại theo schema bạn cần
        df.to_csv(file_path, index=False, encoding="utf-8-sig")
        print(f"Created new file: {file_path}")

# Extract all existing disease names at the start
all_existing_names_set = get_all_existing_disease_names(FOLDER_PATH)

# %%
all_existing_names_set
# Out:
# {'osteo-porosity acuta',
#  'spermatic duct obstructive hyperplasia',
#  'thyro-dysgenesis',
#  'auto-lymphocytosis',
#  'gonadal hormone resistance',
#  'neuro-electrolyte imbalance disorder',
#  'myofascial sheath syndrome',
#  'osteo-myelodegeneration',
#  'gastric lumen atrophy',
#  'auto-crescendo',
#  'vascular attenuata syndrome',
#  'osteo-crystalline decay',
#  'veno-arterial shunt anomaly',
#  'bronchial arborization syndrome',
#  'pulmonary fibroplasty',
#  'spinal cord atrophy syndrome',
#  'bronchial spasm persistentis',
#  'cortical atrophy syndromis',
#  'renal tubular dysfunction',
#  'cerebral demyelination syndrome',
#  'hepatic drift',
#  'synaptic pruning hyperactivity',
#  'pancreo-dysregulation syndrome',
#  'osteo-rigidia',
#  'lympho-stagnation disease',
#  'dermal fibrosis hyperplasia',
#  'enteric hyper-absorption',
#  'adreno-crisis hyper',
#  'pulmonic sclerosis',
#  'pituitary growth factor dysregulation',
#  'nephro-sclerosis progressive',
#  'broncho-alveolar fusion',
#  'dermal fibro-calcification',
#  'dermato-collagenosis atrophicans',
#  'arterial sclerosis',
#  'osteo-degenerative articulosis',
#  'pituitary adenoma secretorius',
#  'atherial sclerosis',
#  'peripheral neuropathic ataxia',
#  'pulmonary septal atrophy',
#  'glandular slumber',
#  'renal filtration cascade failure',
#  'bronchial veil',
#  'pancreatic isletitis autoimmune',
#  'thyro-adrenal cascade',
#  'autoimmune neural destabilization',
#  'autoimmune splenomegaly',
#  'gastric mucosis necrotica',
#  'dermato-neurodermatitis',
#  'follicular hyperkeratosis generalisata',
#  'pulmonary ciliary dyskinesia',
#  'dermal collagen hyper-crosslinking',
#  'thymic overdrive syndrome',
#  'thyro-dysphoria',
#  'neuralgia plexus',
#  'bronchial weep',
#  'neuralgia somnia',
#  'osteo-chondral necrosis',
#  'myofascial compartment disorder',
#  'gastric chronostasis',
#  'arthropathia destructiva progressiva',
#  'spermatic duct atresia congenita',
#  'peripheral neuropathic algia',
#  'enteric neurodysfunction',
#  'hemoglobinic stasis syndrome',
#  'enteric hyperkinetic syndrome',
#  'cerebral cortex atrophy syndrome',
#  'bronchial spasmodic syndrome',
#  'cerebral plexus irritation',
#  'osteo-degeneration accelerata',
#  'articular synovial hyperplasia',
#  'broncho-constrictive apnea',
#  'autoimmune somatic erosion',
#  'pulmonary fibro-ossificans',
#  'dermal fibro-proliferation',
#  'dermal collagen hypertrophy',
#  'renal crystal sclerosis',
#  'derma-pigmentation anomaly',
#  'dermato-pustulosis',
#  'neural glacial atrophy',
#  'entero-dystrophy',
#  'ovarian follicle desiccation',
#  'vascular stasis syndrome',
#  'hypertropic ventriculitis',
#  'endo-pelvic adenosis',
#  'testicular fibrosis indurata',
#  'enteric neuropathy dystrophy',
#  'neutrophil agenesis',
#  'gonadal dysplasia sickness',
#  'sanguine stasis syndrome',
#  'vasculitic purpura chronica',
#  'hepato-cellular cascade',
#  'vascular occlusion syndrome',
#  'pulmonary fibrosis crypta',
#  'venous hyperthrombosis',
#  'bronchial constricta',
#  'dermato-exfoliativa',
#  'dermal glass',
#  'thyroid follicular hyperplasia nodularis',
#  'pancreatic islet dysfunction',
#  'vascular stasis myopathy',
#  'metabolic rift disorder',
#  'vesicular hyperactivity',
#  'bronchial constrictive disorder',
#  'cutaneous neuralgia',
#  'cranio-sensory desync',
#  'autoimmune hyperglobulinemia',
#  'hyper-thyroidic storm',
#  'gonadal hormonal exhaustion',
#  'testicular fibrosis pathogen',
#  'gastric hyperkinesis',
#  'pancreatic desynchronization',
#  'bronchial hyper-reactivity disorder',
#  'cerebral dissonance disorder',
#  'adrenal exhaustion syndrome',
#  'adrenal exhaustion complex',
#  'pan-immuno-deficiency',
#  'myoskeletal rigidity syndrome',
#  'pituitary hypersensitivity',
#  'cardiomyopathic fibrosis',
#  'neuralgia optica',
#  'osteo-fibrotic sclerosis',
#  'gonadal atrophy virus',
#  'autoimmune hypersensitivity',
#  'gastric atrophy plague',
#  'tracheobronchial stenosis idiopathica',
#  'neuro-cognitive atrophy',
#  'gastric echo malabsorption',
#  'hepatic tarnishing',
#  'pancrea-regulitis',
#  'pancreatic hypo-digestion',
#  'osteoarthritic synovitis',
#  'gonadal hypoplasia syndrome',
#  'arterial sclerosis nova',
#  'chrono-stasis syndrome',
#  'lymphatic vessel collapse',
#  'articular calcification disorder',
#  'testicular seminoma proliferans',
#  'cardiac synapse dysrhythmia',
#  'renal calcification cascade',
#  'adrenal shadow syndrome',
#  'bone-sinter disease',
#  'vascular constriction syndrome',
#  'cardiac hypertrophy idiopathica',
#  'epidermal desquamation syndromic',
#  'fibro-cardiac spasm',
#  'gastric stasis syndrome',
#  'bone lattice disorder',
#  'uterine myoma proliferation',
#  'myocardial micro-rupture',
#  'epidermal barrier degeneration',
#  'cerebro-static',
#  'ovarian fibroid dystrophy',
#  'cortical hyperstimulation syndrome',
#  'glomerular dysfunction syndrome',
#  'ovarian fibrocystoma',
#  'pleural miasma',
#  'epidermal slough',
#  'gonadal desynchronosis',
#  'sebaceous gland hyperplasia universal',
#  'gastric dysmotility disorder',
#  'epidermal sclerosis',
#  'pituitary hypofunction disorder',
#  'ovarian cystosis aggregata',
#  'arterial plaquexis',
#  'nephro-glomerular degeneration',
#  'cerebral echo',
#  'skeletal muscle necrosis syndrome',
#  'cerebral myelin atrophy',
#  'osteo-lytic hyperplasia',
#  'pancreatic haze',
#  'renal filtration anomaly',
#  'thyroid gland hyperplasia',
#  'tracheal constriction anomaly',
#  'hepatic scleroma',
#  'chrono-stasis myopathy',
#  'synaptic degeneration complex',
#  'gastric mucosal necrosis',
#  'ossification fibril disorder',
#  'synaptic fog',
#  'epidermal desquamation anomala',
#  'autoimmune histiocytosis',
#  'pituitary desynchronosis',
#  'hormone disharmony disorder',
#  'myofascial calcification diffusa',
#  'gastro-intestinal dysmotility syndrome',
#  'complement deficiency hereditaria',
#  'alveolar adhesion syndrome',
#  'ovarian cystogenesis polyposa',
#  'pulmonary fibrosis idiopathica',
#  'enteric dysmotility paralysis',
#  'dermal keratosis variola',
#  'glomerular membrane fenestration deficiency',
#  'glandular secretion aberration syndrome',
#  'pituitary dysfunction variant',
#  'peripheral artery occlusion disorder',
#  'myofascial contracture disease',
#  'testicular germinal hypoplasia',
#  'nephrotic calcification disorder',
#  'pneumo-fibrotic collapse',
#  'neuro-cognitive ataxia',
#  'dermal hyper-keratosis flux',
#  'cerebral myelin erosion',
#  'ovarian quiescence',
#  'keratinocyte dysplasia',
#  'nephro-concentratia',
#  'osteo-rigidity syndrome',
#  'epidermal dehiscence syndrome',
#  'osteo-chondritis inflammatoria',
#  'synovial gel defect',
#  'bladder neuropathic dysfunction',
#  'adrenal surge',
#  'lupus cutis atypica',
#  'aetheric tremor syndrome',
#  'hepatic glycogenolysis deficiency',
#  'pulmonary fibrosclerosis',
#  'adrenal surge cascade',
#  'histiocytic granulomatosis disseminata',
#  'cortical ataxia syndrome',
#  'alveolar capillaritis obstructiva',
#  'alveolar degeneration syndrome',
#  'bronchial cryptosis',
#  'myofascial tension myopathy',
#  'epidermal hyperkeratosis diffusa',
#  'adrenal cortical hypersecretion syndrome',
#  'ovarian follicular atresia accel',
#  'cerebellar atrophy complex',
#  'neural synaptic atrophy',
#  'pancreatic hyper-secretion syndrome',
#  'thyroidal hypersecretion disorder',
#  'testicular fibroma',
#  'adrenal cortical atrophy',
#  'ureteric stricture disease',
#  'myofascial contracture',
#  'gastric atrophy disease',
#  'melanocytic hyperplasia diffusa',
#  'articular cartilage degeneration',
#  'marrow mirage',
#  'hormonal flux disorder',
#  'dermal pigment irregularity',
#  'bronchial spasm cascade',
#  'renal tubular necrosis (chronic variant)',
#  'cerebro-spinal demyelination',
#  'glomerular sclerosis nephropathy',
#  'glomerular sclerosis obscura',
#  'articular calcification syndrome',
#  'gastric hyperkinesis syndrome',
#  'vasculitis chronica',
#  'hepatic glycogenosis type v',
#  'ureteral obstructive neuropathy',
#  'utero-cervical dysplasia',
#  'subdermal fibrosis syndrome',
#  'dermatolytic pemphigoid acquisitum',
#  'renal silt disorder',
#  'vascular plaquemia',
#  'cartilage erosion sickness',
#  'adrenal cortex insufficiency syndrome',
#  'ovarian follicular atresia prematura',
#  'aortic atheroschlerosis',
#  'ligamentous ossification disease',
#  'uterine endometrial dysplasia',
#  'gastro-motility dysfunction',
#  'epidermal dyskeratosis',
#  'cardio-syncopic collapse',
#  'lymphatic slumber',
#  'ovarian follicle atresia accelerated',
#  'hepatic encephalopathy chronica',
#  'gamete fusion failure',
#  'cerebral synaptic overdrive',
#  'glandulo-atrophy',
#  'vesicular nephrosclerosis',
#  'cardiac glycopenia',
#  'thyroid gland hypofunction',
#  'gonadal atrophia progressiva',
#  'cerebral ataxia complex',
#  'epidermal hyperkeratosis',
#  'cerebral fog aphasia',
#  'alveolar cementosis',
#  'glomerular filtration impairment',
#  'gastric atrophy chronica',
#  'thyroid hypersecretion paradoxa',
#  'bronchial weave disease',
#  'lymphoid depletion virus',
#  'autoimmune lymphocytic plerosis',
#  'bladder neurogenic dysfunction',
#  'renal glomerular occlusion',
#  'chondral calcification sclerosis',
#  'neuro-synaptic flicker',
#  'cartilage ossification syndrome',
#  'pancreo-islet dysfunction',
#  'gastric hyperfermentation',
#  'bronchial dilation anomaly',
#  'retina-desiccation syndrome',
#  'immunoglobulin receptor desensitization',
#  'vascular calcificitis',
#  'testicular venostasis',
#  'neuro-tremor sclerosis',
#  'uterine ectopic implantation syndrome',
#  'lymphatic stasis disorder',
#  'pulmonic glaze',
#  'adrenal cortical hyperplasia',
#  'autoimmune receptor mimicry',
#  'gastro-motility dyskinesia',
#  'uro-cystic neuropathy',
#  'pancreatic insufficiency reactiva',
#  'lymphoid hyper-reactivity disorder',
#  'myofibril dystrophic spasm',
#  'bronchial hyperreactivity syndrome',
#  'synaptic hyperactivity disorder',
#  'follicular atrophy',
#  'osteomalacia resistentia',
#  'myofiber atrophy accelerated',
#  'renal tubulopathy acquisita',
#  'myo-fibril rigor',
#  'aortic flutter',
#  'enteric nerve hypoplasia',
#  'bronchial hyperplasia obstructiva',
#  'pulmonary fibro-sclerosis',
#  'dermato-neurotic eczema',
#  'bronchial congealment',
#  'utero-endometriosis diffusa',
#  'bronchial hyperreactivity disorder',
#  'pulmonic fibro-restrictive disease',
#  'glomerular sclerosis complex',
#  'cerebral echo syndrome',
#  'auto-cytotoxin syndrome',
#  'pulmonary fibrosis syndrome',
#  'myo-fade syndrome',
#  'gamete maturation disorder',
#  'immunocore collapse',
#  'pulmonary fibrosis diffusa',
#  'nephro-sedimentation',
#  'ovarian follicular dysgenesis',
#  'vena cava occlusion syndrome',
#  'endometriotic hyperproliferation',
#  'synaptic veil',
#  'gastro-neuronal dysmotility',
#  'renal tubular sclerosis',
#  'gastro-osmotic dysplasia',
#  'pancreatic insufficiency hereditaria',
#  'hepatic glycogenosis',
#  'lymphatic mire',
#  'intestinal glyph',
#  'vena stasis syndrome',
#  'renal glomerulosclerosis',
#  'hemostasis anomaly',
#  'pancreatic islet atrophy',
#  'uterine hyperplasia cystica',
#  'gastro-esophageal peristaltic reversal',
#  'myofibril degeneration disease',
#  'testicular atrophy progressive',
#  'myofibril degeneration syndrome',
#  'pituitary hyper-secretion disorder',
#  'gastric whisper',
#  'pituitary microadenoma syndrome (non-secreting)',
#  'pancreatic insulinitis',
#  'thymic auto-immunity',
#  'glandular exhaustion syndrome',
#  'thyro-adrenal exhaustion',
#  'subcutaneous lipomatosis multifocal',
#  'bronchial atrophy',
#  'neuro-spike syndrome',
#  'neuro-synaptic dysregulation',
#  'bladder dysmotility neuropathica',
#  'hepatic mire',
#  'subcutaneous adipose necrosis',
#  'ovarian follicle atrophy',
#  'auto-lymphocytic hyperactivity',
#  'seminal vesicle calcification',
#  'immunodeficiency spleen syndrome',
#  'reproductive dysplasia syndrome',
#  'hepatic cystic dystrophy',
#  'immunodeficiency phagocytosis defect',
#  'aterial sclerosis',
#  'alveolar wall remodeling disease',
#  'enteric motility dysfunction',
#  'gona-dysphoria syndrome',
#  'epidermal dysplasia bullosa',
#  'synaptic pruning disorder',
#  'cartilage erosion disorder',
#  'gastric mucosal atrophy',
#  'vascular decay syndrome',
#  'enteric atrophy degenerative',
#  'spinal myelin desiccation',
#  'osteo-fibrillosis',
#  'hepatic encephalopathy occulta',
#  'arterial plaque resorption syndrome',
#  'osteo-fibrinosis',
#  'cortical shiver',
#  'epidermal sloughing disorder',
#  'adrenal cortex insufficiency chronica',
#  'epidermal desquamation flux',
#  'gut-flux syndrome',
#  'ovarian cystic proliferation',
#  'immunodeficiency variabilis communis',
#  'lymphatic stagnation syndrome',
#  'synaptic desynchronosis',
#  'synaptic erosion disorder',
#  'hemostatic dysregulation syndrome',
#  'ventricular myocarditis strain',
#  'cranial nerve demyelination',
#  'nephrolithic aggregation disorder',
#  'cardiac atonia',
#  'pulmonary silicosis nova',
#  'ovarian cystic adenomatosis',
#  'hepatic glycogen dysregulation',
#  'glomerular haze',
#  'myo-contracture syndrome',
#  'ureteral scorch',
#  'articular cartilage erosion',
#  'pulmonary fibrosis exacerbata',
#  'renal calcification anomaly',
#  'pneumo-sclerosis',
#  'glomerular nephropathy variant',
#  'capillary obfuscation syndrome',
#  'bronchial-hyperplasia',
#  'hypothyroidic swell',
#  'spermatic duct occlusion syndrome',
#  'atrial flutter syndrome',
#  'cerebellar atrophy idiopathica',
#  'immuno-hyperreactivity',
#  'renal crystalluria obscura',
#  'myofibril desynchronosis',
#  'entero-gastric dysmotility',
#  'lymphoid atrophy morbidity',
#  'autoimmune melanocytolysis',
#  't-cell receptor dysregulation',
#  'ovarian cystic metamorphosis',
#  'osteo-fissure disease',
#  'neuro-sensory hypersensitivity',
#  'glomerulonephritis chronica idiopathica',
#  'renal filtration collapse',
#  'neuralgia ataxic syndrome',
#  'adrenal insufficiency crisis',
#  'pulmonary alveolar sclerosis',
#  'pneumo-sequestration',
#  'autoimmune lymphadenopathy',
#  'gastric ulcerosis',
#  'enteric neuropathy syndrome',
#  'bronchial spasm atypicalis',
#  'cerebral synaptic decay',
#  'adrenal hyper-sensitia',
#  'testicular germinal aplasia',
#  'testicular seminiferous tubule sclerosis',
#  'adrenal cortex exhaustion',
#  'alveolar fibrotic disease',
#  'adrenal cortical hyper-responsiveness',
#  'osteo-porous brittleness',
#  'testicular microcalcification disorder',
#  'gastro-lumen atrophy',
#  'hemodynamic sluggishness',
#  'adrenal hyperplasia variant',
#  'dermal calcification syndrome',
#  'enteric motility dysphoria',
#  'thymic auto-rejection',
#  'ureteral obstructive nephropathy',
#  'hepatic micro-thrombosis syndrome',
#  'synaptic degeneration syndrome',
#  'tracheal cartilage degeneration',
#  'gastro-peristaltic dysfunction',
#  'joint cartilage dessication',
#  'pulmonary fibronexus',
#  'pneumo-ventilosis',
#  'dermal fibroid hyperplasia',
#  'thyro-metabolic flux',
#  'xeroderma pigmentosum acquisitum',
#  'cranial oscillation syndrome',
#  'hepatic lipidosis fibroticans',
#  'arterial shiver',
#  'osteo-calcification anomaly',
#  'synaptic decoupling disease',
#  'gloom-lung fibrosis',
#  'dermal crystalization disease',
#  'cerebral plexus dysregulation',
#  'granulomatous immunopathy',
#  'thyro-dysregulation',
#  'cardiac arrhythmia flux',
#  'neuronal hyperkinesia',
#  'cortical sensory aphasia',
#  'dermal keratosis accelerata',
#  'pulmonary petrifying disease',
#  'hepatic steatofibrosis',
#  'vasculo-atrophy',
#  'bladder detrusor hyperactivity',
#  'cerebral ataxia minoris',
#  'testicular microlithiasis syndromica',
#  'arterial calcification syndrome',
#  'uterine endometrial hyperplasia',
#  'hepatic fibrosis proliferans',
#  'b-lymphocyte dysregulation disorder',
#  'vascular collapse syndrome',
#  'hepatic glycogen collapse',
#  'autoimmune lymphatic swell',
#  'osteo-rigiditas',
#  'neuro-synaptic degeneration',
#  'enteric motility disruption',
#  'renal calcification disorder',
#  'myo-fibril atrophy',
#  'adenoma hyper-secretorius',
#  'ureteral spasm dystrophy',
#  'epidermal dysplasia hereditaria',
#  'neural static dementia',
#  'ovarian cystic metaplasia',
#  'pneumonic calcificans',
#  'alopecia universalis fulminans',
#  'dermal keratolysis',
#  'hepatitis chroma',
#  'cerebro-myalgia syndrome',
#  'adrenal hyperplasia syndrome',
#  'osteo-ligamentous atrophy',
#  'dermal angiopathy progresiva',
#  'immuno-phantom',
#  'diencephalic demyelination syndrome',
#  'endometrial hyperplasia variant',
#  'cytokine storm anomaly',
#  'alveolar fusion disorder',
#  'epidermal ichthyosis keratosis',
#  'subcutaneous lipodystrophy',
#  'hemorheological stasis disease',
#  'immunosuppression paradoxa',
#  'nephron sclerosis progressiva',
#  'pulmonary bloom syndrome',
#  'bronchial constrictor syndrome',
#  'cardio-renal dystrophy',
#  'lymphatic petrifactio',
#  'nephro-filtration collapse',
#  'neuralgic migrainoma',
#  'bronchial ciliary dysfunction',
#  'arterial sclerosis accelerata',
#  'dermo-scaly dermatitis',
#  'neural glare impairment',
#  'renal filtrate disruption',
#  'dermal atrophic angioma',
#  'myofascial adhesion syndrome',
#  'adrenal hypersecretion chronic',
#  'ligamentous calcification disorder',
#  'dermal xerosis hyalinosis',
#  'cardio-vascular constriction syndrome',
#  'gastric-stasis aplasia',
#  'dermal elasticity decay',
#  'dermatitis granulomatosa',
#  'osteo-fibrotic myopathy',
#  'lymphocyte depletion crisis',
#  'autoimmune glomerulopathy',
#  'alveolar fibrosis syndrome',
#  'dermato-vascular atrophy',
#  'neuro-ataxia dystrophy',
#  'bronchial hyper-reactio',
#  'gonadal dysgenesis syndrome',
#  'autoimmune dermalitis',
#  'capillary permeability fluctuation',
#  'sebaceous gland anomaly',
#  'autoimmune hyper-inflammation syndrome',
#  'alveolar fibrotic weave',
#  'myofibril ataxia syndrome',
#  'cholecysto-hepatic dysbiosis',
#  'auto-aggressive lymphadenopathy',
#  'cardio-myopathy restrictiva',
#  'bronchial spasmodic disease',
#  'ureteric spasm disorder',
#  'prostatic hypertrophia inflammatoria',
#  'autoimmune lymphocyte apoptosis',
#  'subcutaneous lipoatrophy',
#  'enteric hypomotility dystrophy',
#  'glomerular hyperfiltration sclerosis',
#  'bronchiolitis constrictiva',
#  'osteo-lytic melt',
#  'hormonal echo',
#  'gastro-enteric neuropathy',
#  'vesicular spasm syndrome',
#  'pleural effusion chronica',
#  'autoimmune myelin destruction',
#  'hyper-vigilance autoimmune encephalitis',
#  'synaptic flicker syndrome',
#  'kerato-pigmentosa variabilis',
#  'pleural effusion hyperflux',
#  'sebaceous gland hypertrophy systemic',
#  'cardio-syncope syndrome',
#  'pituitary glitch disorder',
#  'immunodeficiency variabilis hereditaria',
#  'ureteral peristalsis dyskinesia',
#  'autoimmune erythrocytosis',
#  'vasculitis lividus',
#  'adrenal hyperplasia congenitalis',
#  'lymphoid suppression sickness',
#  'cryodermia',
#  'endometriosis invasiva',
#  'pancreatic islet cell hyperplasia',
#  'testicular lysis syndrome',
#  'bronchial dysmotility',
#  'pancreatic islet fatigue',
#  'pulmo-fibrosis obscura',
#  'autoimmune cell atrophy',
#  'peripheral neuropathy inducta',
#  'subdermal hematic pool',
#  'immunoglobulin defectiva',
#  'entero-colonic dysbiosis',
#  'arteria sclerosis',
#  'ligamentum ossificans',
#  'dermatitis fungalus extensive',
#  'bladder neuropathy spastica',
#  'bladder atonia complex',
#  'enteric rust',
#  'neural synaptic fade',
#  'pituitary adenoma secretory',
#  'pancreatic islet atrophy progressiva',
#  'lymphocyte hyperactivity disorder',
#  'glandular hyperactivity syndrome',
#  'synaptic disconnect disorder',
#  'immunocomplex vasculopathy',
#  'ureteral atresia congenitalis',
#  'myofibril atrophic dystrophy',
#  'cardio-myofibril degeneration',
#  'renal filtration dysfunction',
#  'nephro-sclerosis obliterans',
#  'immunal overdrive disorder',
#  'epidermal delamination disorder',
#  'epidermal calcification plaques',
#  'osteo-fibrin myopathy',
#  'gut glaze',
#  'osteo-myofascial fusion',
#  'uterine adenomyoma diffusum',
#  'immunocomplex vasculitis systemica',
#  'bronchial constriction cascade',
#  'pleural obfuscation syndrome',
#  'alveolar permeability flux',
#  'gonadal stasis affliction',
#  'subdermal fibrosis',
#  'ovarian follicle dysfunction',
#  'subdermal lipomatosis',
#  'neuro-sensory atrophy',
#  'enteric dysmotility syndrome',
#  'neuralgia chronica',
#  'dermo-lattice disease',
#  'ureteral atresia',
#  'lumin-dermapathy',
#  'glandular hyper-proliferation',
#  'autoimmune lymphocytic encephalitis',
#  'vasculitis purpura',
#  'cerebellar ataxia syndrome',
#  'subcutaneous lipoma plexus',
#  'melanin hyper-volatility',
#  'cytokine storm cascade',
#  'enteric plexus neuropathy',
#  'vascular seepage disease',
#  'pancreatic islet insufficiency',
#  'hypo-venous constriction syndrome',
#  'testicular fibro-sclerosis',
#  'lymphatic hypoplasia congenital',
#  'dermal elastosis progressive',
#  'dermato-pustulosis chronicus',
#  'cortical desynchronization disorder',
#  'thyroid gland hyperfunction',
#  'immunodeficiency varient',
#  'adreno-insufficiency chronica',
#  'pancreatic islet necrosis',
#  'aorta-flutter',
#  'cerebral hypoxia insidiosa',
#  'myocardial septal calcification',
#  'neuralgia chromatism',
#  'renal cystic dysplasia',
#  'osteo-synovial erosion',
#  'hepatic necrosis idiopathica',
#  'capillary leak syndrome chronic',
#  'adrenal cortical hyperplasia congenita',
#  'cardio-atrophy syndrome',
#  'renal tubular degenerosis acuta',
#  'lympho-parasitic inversion',
#  'sebaceous gland hypersecretion disorder',
#  'subdermal collagen accumulation disorder',
#  'bronchial collapse syndrome',
#  'enteric plexus degeneration',
#  'thyro-adrenal dysfunction',
#  'urethral stenosis congenita',
#  'venaflux syndrome',
#  'pulmonary sclerosis',
#  'neuromuscular dysteleology',
#  'tracheal spasmia',
#  'gastric atrophy sickness',
#  'autoimmune lymphadenopathy systemica',
#  'alveolar collapse disorder',
#  'immunosynaptic atrophy',
#  'epididymitis chronic',
#  'gastric hypomobility',
#  'ovarian cystic dystrophy',
#  'follicle frost',
#  'atrial brady-pulse',
#  'enteric motility stasis',
#  'renal calcification',
#  'fibro-myalgia chronica',
#  'vascular calcification syndrome',
#  'ligamentous fragility disorder',
#  'arterial calcificosis',
#  'cardio-vascular dysrhythmia',
#  'spermatic duct blockage',
#  'androgen flux disease',
#  'utero-fibroid proliferation',
#  'neuro-synaptic decay',
#  'neural staticus',
#  'bronchial bloom',
#  'ossific myopathy',
#  'aortic sclerosis plexus',
#  'synovial desiccation',
#  'ureteric dyskinesia',
#  'cardiac myofibril atrophy',
#  'cerebro-synaptic decay',
#  'nephron coagulation disorder',
#  'lymphocytic dysregulation',
#  'tendonitis calcificans amplified',
#  'tracheal stenopathy',
#  'lymphatic atrophy syndrome',
#  'dermal collagenopathy',
#  'systemic inflammatory response hyperplasia',
#  'nephrocystic dysplasia adultorum',
#  'ureteral stenosis progressive',
#  'thyroid hyper-secretion syndrome',
#  'gonadal dysgenesis chronica',
#  'gastro-intestinal motility atonia',
#  'adreno-cortical exhaustion',
#  'ovarian cystic swarm',
#  'pneumo-lace disease',
#  'lymphoid hyperplasia autoimmune',
#  'cognito-fog disorder',
#  'gastro-enteric malabsorption syndrome',
#  'pustular psoriasis exacerbans',
#  'hepatic lipidosis syndrome',
#  'alveolar degeneration phlogistica',
#  'pulmonary crystallosis',
#  'pneumo-fibrosis',
#  'epidermal crystallization disease',
#  'cerebral plexopathy syndrome',
#  'glomerular filtration hyperplasia',
#  'gastric lumen overgrowth',
#  'capillary leak syndrome',
#  'thyroid follicular insufficiency',
#  'auric flutter',
#  'uretero-stenosis calcific',
#  'immuno-deficiency complex heredita',
#  'bronchial constriction syndrome',
#  'hepatic cirrhosis cholestasis',
#  'ovarian crystal disease',
#  'ureteral stricture idiopathic',
#  'chromalgi vasculorum',
#  'dermal graft rot',
#  'gonadal atrophy progressive',
#  'autoimmune glomerulitis',
#  'ovarian cystic hyperplasia',
#  'arterial webbing disease',
#  'pituitary gland hyposecretion',
#  'epidermal desquamation syndrome',
#  'ligamentous laxity syndrome',
#  'cerebral myelin degradation',
#  'ureteral atony',
#  'epidermal ghosting',
#  'lymphatic bloom',
#  'ureteral stricture syndrome',
#  'gastrointestinal dysmotility pervasive',
#  'bronchial spasmodic dystrophy',
#  'epidermal desquamation profunda',
#  'autoimmune cytopenia',
#  'thyroid glandular sclerosis',
#  'ligamentous calcification syndrome',
#  'hepatic steatosis progressive',
#  'ovarian follicle atresia precox',
#  'ovarian follicle depletion',
#  'autoimmune vasculitis systemica',
#  'glomerular hyperfiltration disease',
#  'prismatic dermatitis',
#  'microvascular occlusion disease',
#  'neuropathy hypersensitivum',
#  'dermatitis exfoliativa chronica',
#  'hemostasis hyper-reactiva',
#  'enteric malabsorption syndrome',
#  'adrenocortical exhaustion syndrome',
#  'atrial fibrillation aberrans',
#  'ovarian-sclerotic syndrome',
#  'pulmonary silicosis',
#  'epidermal atrophy profunda',
#  'adrenal exhaustion disorder',
#  'arterial spasmosis',
#  'alveolar calcification disease',
#  'osteo-chondro dysmorphia',
#  'testicular atrophy syndrome',
#  'spinal myelopathy acuta',
#  'tendon weave',
#  'uterine endometriosis prolifera',
#  'alveolar glaze disease',
#  'cerebral dyskinesia',
#  'immunodeficiency acquisita profunda',
#  'renal tubule calcification',
#  'hepatic glucosuria',
#  'neuralgia hyperesthetica',
#  'ureteral obstruction minor',
#  'ligamentous hyper-laxity',
#  'osteo-myelitis chronica',
#  'ovarian follicular arrest syndrome',
#  'pulmonary alveolar fibrosis',
#  'cystic dysuria syndrome',
#  'epidermal bloom',
#  'arterial spasmica',
#  'adrenal dissonance disorder',
#  'subdermal vascular atrophy',
#  'epidermal melanocyte dysplasia',
#  'nephrolithiasis recurrens',
#  'nephro-sclerosis progressiva',
#  'adrenal hypersecretion anomaly',
#  'ligamentous laxity syndromica',
#  'hypothalamic drift',
#  'bladder sphincter dystrophy',
#  'myofascial atrophy syndrome',
#  'osteo-brittleness disorder',
#  'pulmonary fibrostenosis',
#  'gastric motility dysphoria',
#  'venous calcification disorder',
#  'glomerular sclerosis virus',
#  'gastric mucosa hypoplasia',
#  'gamete dysgenesis syndrome',
#  'hepatic metabolic dysfunction',
#  'sebaceous gland hyperplasia',
#  'renal filter disorder',
#  'pancreatic slumber',
#  'lymphocyte depletion syndrome',
#  'bladder neuropathy syndrome',
#  'myofascial constriction syndrome',
#  'testicular oligosperma',
#  'hepatic cholestasia',
#  'adrenal hyperplasia congenita',
#  'ureteric dysmotility',
#  'lymphocytic depletion syndrome',
#  'myo-lysis atypica',
#  'follicular choke',
#  'osteo-lytic syndrome',
#  'ureteral neuropathic dysfunction',
#  'neural flicker',
#  'myo-dystrophic creep',
#  'epidermal desquamation disorder',
#  'bladder desiccation syndrome',
#  'suprarenal exhaustion',
#  'vascular calcifiber',
#  'myofibril atrophy syndrome',
#  'cysto-nephritis chronic',
#  'glomerular hyperpermeability',
#  'myofascial contracture disorder',
#  'bronchiolitis obstructiva',
#  'uterine myometrial dysplasia',
#  'kerato-dysplasia universal',
#  'testicular genesis failure',
#  'adreno-exhaustion disorder',
#  'athero-glacial disease',
#  'vascular weave',
#  'enteric neuropathy complex',
#  'coronary vasculitis chronica',
#  'tendon degeneration malady',
#  'auto-lymphocytic rage',
#  'ovarian cystic atrophy',
#  'ureteral peristaltic dyscoordination',
#  'ureteral obstruction syndrome',
#  'glandular hypo-secretory drift',
#  'veno-occlusive sclerosis',
#  'immunodeficiency cytopenia',
#  'veno-occlusive cardiomyopathy',
#  'gonadal atrophy syndrome',
#  'venous bloom',
#  'nephrogenic diabetes insipidus acquired',
#  'renal tubular necrosis proliferation',
#  'arterial sclerosis obliterans',
#  'autoimmune cytokine storm',
#  'adrenal cortical exhaustion',
#  'glandular slumber syndrome',
#  'synaptic overdrive',
#  'auto-inflammatory cascade',
#  't-cell receptor anergy',
#  'synovial arthrosis',
#  'vesical rigor',
#  'immunodeficiency anomaly x',
#  'cardio-syncrisis',
#  'myo-fibril decay',
#  'phagocytic lethargy',
#  'cardio-thrum syndrome',
#  'pneumonia fibrilosa',
#  'myofibril atrophy',
#  'ovarian petrify',
#  't-cell depletion syndrome',
#  'gonadal hormone dysregulation',
#  'immune sieve syndrome',
#  'veno-stasis syndrome',
#  'cerebellar ataxia onset',
#  'myofibril atrophy progressiva',
#  'fertility wither',
#  'ovarian dormancy syndrome',
#  'pancreatic islet desiccation',
#  'epidermal barrier collapse',
#  'pancreatic enzyme hypersecretion syndrome',
#  'tendino-ligamentous ossification',
#  'neuro-spectral atrophy',
#  'hemo-stasis flux',
#  'ureteral peristalsis dysrhythmia',
#  'autoimmune vasculitis nodus',
#  'cerebrospinal myelinolysis',
#  'osteo-ligamentous degeneration',
#  'uterine myo-sclerosis',
#  'synaptic decay disease',
#  'testicular fade',
#  'osteoarthropathy deformans',
#  'hepatic glycogenolysis dysregulation',
#  'cysto-ureteral reflux',
#  'ligamentous laxity disorder',
#  'renal tubule dysfunction congenita',
#  'jejunal villous atrophy syndrome',
#  'uterine endometrioma multiplis',
#  'bronchial spasmosis',
#  'dermal keratolytic syndrome',
#  'erythrocytic dysplasia',
#  'gonadal fibrotic atrophy',
#  'intestinal rigor mortis',
#  'enteric neuroplasia',
#  'vascular ataxia',
#  'gastro-enteric dysmotility',
#  'vasculitis obscura',
#  'lymphoproliferative autoimmune disease',
#  'bronchial mucociliary dysplasia',
#  'auto-lymphocytic overdrive',
#  'bronchial constriction disease',
#  'adrenal hypersecretion syndrome',
#  'autoimmune dermal desquamation',
#  'thyro-metabolic imbalance',
#  'uterine adenomyosis chronic',
#  'myofibrillar myopathy',
#  'renal-crystallopathy',
#  'vascucleitis',
#  'cardio-atheroma sclerosis',
#  'tendon sheath crystallopathy',
#  'peripheral axon demagnetization',
#  'epidermal atrophy syndrome',
#  'dermal collagen degradation',
#  'epidermal dysplasia exfoliativa',
#  'auto-rejection disease',
#  'crystalline calculus affliction',
#  'osteo-fragilitas',
#  'glomerular sclerosis diffusa',
#  'renal tubular acidosis',
#  'epidermal keratinocyte dysplasia',
#  'hemato-stasis syndrome',
#  'glomerular hyperpermeability syndrome',
#  'hyper-thymic burst',
#  'renal tubular acidosis complex',
#  'osteo-degenerative myopathy',
#  'hepato-sclerosis',
#  'cerebral synapse fade',
#  'myofibril weakness syndrome',
#  'osteo-fibrin deficit',
#  'autoimmune cytokine storm syndrome',
#  'bronchial hyper-reactivity necrosis',
#  'cranial nerve hyperesthesia',
#  'glandulo-sterility',
#  'crimson-tide anemia',
#  'neural glitch syndrome',
#  'myofascial pain syndrome chronic',
#  'capillary leakage encephalopathy',
#  'lymphatic stagnation disease',
#  'vesical neuropathy idio',
#  'lymphatic desensitization disorder',
#  'capillary leak ataxia',
#  'subdermal pruritus nebula',
#  'pancreatic islet dysregulation',
#  'ovarian sclerocystic disease',
#  'alveolar collapse disease',
#  'aortic calcification syndrome',
#  'cortical excitation deficit',
#  'bronchial atrophy syndrome',
#  'uro-stasis syndrome',
#  'alveolar calcification disorder',
#  'cortical seizure cascade',
#  'thyroid hypersecretion disorder',
#  'dermal petrification',
#  'bladder bloom',
#  'epidermal desquamation chronica',
#  'hepatic crystalline disease',
#  'gastric erosion syndrome',
#  'ovarian hyperplasia syndrome',
#  'synaptic fade',
#  'lymphocytic hyperproliferation',
#  'nephro-glomerulosis',
#  'myalgia fasciculata',
#  'dermal collagen cross-linking disorder',
#  'ovarian folliculitis chronic',
#  'gonadal dysgenesis atypical',
#  'hepato-spleenic dysplasia',
#  'pulmonary fibrocystosis',
#  'alveolar collapse chronica',
#  'lymphatic atrophy disease',
#  'aortic flutter syndrome',
#  'ovarian sclerocystosis',
#  'glyco-pancreatic dysregulation',
#  'subdermal atrophy morbus',
#  'cerebral glial dyskinesia',
#  'renal tubule occlusion disease',
#  'pancreatic insufficiency genetic',
#  'testicular glimmer',
#  'cortical flicker syndrome'}

# %%
# --- Main Execution ---
if __name__ == "__main__":
    FILE_NAME_1 = "client_3_data.csv"
    file_path = os.path.join(FOLDER_PATH, FILE_NAME_1)
    (file_path)
    # Begin loop to reach target N
    while True:
        # 1. Determine current and needed counts
        existing_names_set = get_existing_disease_names(FILE_NAME_1)
        current_count = len(existing_names_set)
        
        TARGET_N = 300  # <--- TARGET SỐ BẢN GHI CẦN ĐẠT ĐƯỢC
        BATCH_SIZE = 20 # <--- NUMBER OF DISEASES TO GENERATE PER API CALL
        print("-" * 50)
        print(f"Number of existing records: {current_count}")
        
        # Stop if target reached
        if current_count >= TARGET_N:
            print(f"Reached target of {TARGET_N} records. Exiting.")
            break
            
        remaining_needed = TARGET_N - current_count
        
        # The last API call doesn't need to generate full BATCH_SIZE if fewer are needed
        entries_to_generate = min(BATCH_SIZE, remaining_needed)
        print(f"Needing {remaining_needed} more records. Requesting Gemini to generate {entries_to_generate} records.")

        # 2. Prepare prompt and call Gemini API
        prompt = prepare_simple_prompt(entries_to_generate)

        # 3. Generate and parse data from Gemini
        final_data_raw = generate_and_parse_diseases(prompt) 
        
        if not final_data_raw:
            print("❌ Không nhận được dữ liệu từ Gemini. Tạm dừng để kiểm tra lỗi API.")
            break # Thoát nếu API lỗi

        # 3. Filter out duplicates
        unique_new_data, duplicates_removed = filter_new_data(final_data_raw, existing_names_set) # First filter against current file
        unique_new_data, duplicates_removed_1 = filter_new_data(unique_new_data, all_existing_names_set) # Then filter against all files


        if duplicates_removed > 0:
            print(f"- Eliminated {duplicates_removed} duplicate entries from generated data.")
        if duplicates_removed_1 > 0:
            print(f"- Eliminated {duplicates_removed_1} duplicate entries against global data.")

        # 4. Save only unique new data to CSV
        if unique_new_data:
            
            append_to_csv(unique_new_data,FILE_NAME_1)
            print(f"Saved {len(unique_new_data)} new records to file: {FILE_NAME_1}")

        else:
            print("All generated data were duplicates or invalid. Retrying later.")
            
        # Sleep to avoid rate limiting
        time.sleep(5)
# Out:
# --------------------------------------------------
# Tổng số bản ghi hiện có: 0
# Cần thêm 300 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 19
# Cần thêm 281 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 5 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 15 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 15 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 34
# Cần thêm 266 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 4 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 16 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 16 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 50
# Cần thêm 250 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do Gemini không tuân thủ.
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 68
# Cần thêm 232 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 86
# Cần thêm 214 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 104
# Cần thêm 196 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 122
# Cần thêm 178 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 141
# Cần thêm 159 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 159
# Cần thêm 141 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 177
# Cần thêm 123 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 19 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 19 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 196
# Cần thêm 104 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 6 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 14 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 14 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 210
# Cần thêm 90 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 228
# Cần thêm 72 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 3 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 17 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 17 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 245
# Cần thêm 55 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 2 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 18 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 263
# Cần thêm 37 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 3 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 17 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 17 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 280
# Cần thêm 20 bản ghi. Đang yêu cầu Gemini sinh 20 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 3 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 17 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 17 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 297
# Cần thêm 3 bản ghi. Đang yêu cầu Gemini sinh 3 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
# 🚨 Đã loại bỏ 1 bản ghi trùng lặp do trùng với dữ liệu toàn cục.
#
# ✅ Đã lưu tiếp 2 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 2 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 299
# Cần thêm 1 bản ghi. Đang yêu cầu Gemini sinh 1 bản ghi.
# Đang gọi API Gemini để tạo dữ liệu...
#
# ✅ Đã lưu tiếp 1 bản ghi mới vào tệp: client_3_data.csv
# Đã lưu tiếp 1 bản ghi mới vào tệp: client_3_data.csv
# --------------------------------------------------
# Tổng số bản ghi hiện có: 300
# 🎉 Đã đạt mục tiêu 300 bản ghi. Kết thúc chương trình.
